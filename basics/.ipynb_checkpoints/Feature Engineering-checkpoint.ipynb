# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Correlation Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('data.csv')

# %%
# Draw heat map. Light colors mean correlation is high.
plt.figure(figsize=(18,18))
sns.set(font_scale=1.4)
sns.heatmap(df.corr(), annot = True ,linewidths=.1)

# %%
# Returns a list of high correlated series
def high_correlated_columns(dataset, threshold=0.9):
    corr_mat = dataset.corr()
    corr_mat.loc[:, :] = np.tril(corr_mat, k=-1)
    already_in = set()
    result = []
    for col in corr_mat:
        perfect_corr = corr_mat[col][abs(corr_mat[col])> threshold].index.tolist()
        if perfect_corr and col not in already_in:
            already_in.update(set(perfect_corr))
            perfect_corr.append(col)
            result.append(perfect_corr)
    select_nested = [f[1:] for f in result]
    select_flat = [i for j in select_nested for i in j]
    return select_flat

# %%
cols_hc = high_correlated_columns(df)

# Remove target column
if 'target' in cols_hc:
    cols_hc.remove('target')

df_lc = df.drop(columns=cols_hc)
df_lc.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 1   37    male   2       130   250    0        1      187      0      3.5
# 2   41  female   1       130   204    0        0      172      0      1.4
# 3   56    male   1       120   236    0        1      178      0      0.8
# 4   57  female   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
# Display correlated series to the target (These are the most important series)
abs_correlation_matrix = abs(df.corr())
correlations_to_target = abs_correlation_matrix.target.drop('target')
sorted_correlations_to_target = correlations_to_target.sort_values()

sorted_correlations_to_target.plot(kind='barh')

# %% [markdown]
# ## Convert Categorical Variables into Dummy Variables

# %% [markdown]
# Bucket data such as cp, sex can be converted to several binary series. (similar to one hot arrays)

# %%
df.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   3       145   233    1        0      150      0      2.3
# 1   37    male   2       130   250    0        1      187      0      3.5
# 2   41  female   1       130   204    0        0      172      0      1.4
# 3   56    male   1       120   236    0        1      178      0      0.8
# 4   57  female   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
df['sex'] = df['sex'].astype('object')
df['cp'] = df['cp'].astype('object')
df['fbs'] = df['fbs'].astype('object')
df['restecg'] = df['restecg'].astype('object')
df['exang'] = df['exang'].astype('object')
df['slope'] = df['slope'].astype('object')
df['thal'] = df['thal'].astype('object')
df.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs          object
# restecg      object
# thalach       int64
# exang        object
# oldpeak     float64
# slope        object
# ca            int64
# thal         object
# target        int64
# dtype: object

# %%
df_1 = pd.get_dummies(df, drop_first=True)
df_1.head()
# Out:
#    age  trestbps  chol  thalach  oldpeak  ca  target  sex_male  cp_1  cp_2  \
# 0   63       145   233      150      2.3   0       1         1     0     0
# 1   37       130   250      187      3.5   0       1         1     0     1
# 2   41       130   204      172      1.4   0       1         0     1     0
# 3   56       120   236      178      0.8   0       1         1     1     0
# 4   57       120   354      163      0.6   0       1         0     0     0
#
#    cp_3  fbs_1  restecg_1  restecg_2  exang_1  slope_1  slope_2  thal_1  \
# 0     1      1          0          0        0        0        0       1
# 1     0      0          1          0        0        0        0       0
# 2     0      0          0          0        0        0        1       0
# 3     0      0          1          0        0        0        1       0
# 4     0      0          1          0        1        0        1       0
#
#    thal_2  thal_3
# 0       0       0
# 1       1       0
# 2       1       0
# ...
